# %% [markdown]
# # Bai 1

# %%
n=int(input())
tong = 0
for i in range(1,n+1):
    tong += i
print(f'Tổng từ 1 đến {n} là: {tong}')
# Out:
# Tổng từ 1 đến 1000 là: 500500

# %% [markdown]
# # Bai 3

# %%
n=int(input())
giaithua=1
for i in range(1,n+1) :
    giaithua *= i
print(f' Giai thừa của số {n} là: {giaithua}')
# Out:
#  Giai thừa của số 6 là: 720
